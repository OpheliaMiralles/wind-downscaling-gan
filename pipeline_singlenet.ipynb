# %% [markdown]
# # Wind Downscaling
#
# ## Prerequisites
#
# * Conda environment
# * Get a Copernicus API key from: https://cds.climate.copernicus.eu/api-how-to
#   * create a file at \$HOME/.cdsapirc with the required UID and key
# * Create a .env file in the same folder as this notebook, and add the COSMO_USERNAME and COSMO_PASSWORD to connect to the UNI-BE server

# %% [markdown]
# ## Install the required packages

# %%
from datetime import date
from pathlib import Path
import os

# %%
if Path('./setup.py').exists():
    # !pip install -e .
else:
    # !pip install -U git+https://github.com/OpheliaMiralles/WindDownscaling_EPFL_UNIBE.git
# Out:
# Obtaining file:///Users/Boubou/Documents/GitHub/WindDownscaling_EPFL_UNIBE
# Installing collected packages: downscaling
#   Attempting uninstall: downscaling
#     Found existing installation: downscaling 1.0
#     Uninstalling downscaling-1.0:
#       Successfully uninstalled downscaling-1.0
#   Running setup.py develop for downscaling
# Successfully installed downscaling-1.0

# %%
# !conda install -y -c conda-forge gdal tensorflow xarray numpy=1.19.5 pandas pysftp cdsapi elevation rasterio dask python-dotenv
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !pip install topo-descriptors
# Out:
# Requirement already satisfied: topo-descriptors in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: pandas in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from topo-descriptors) (1.3.3)
# Requirement already satisfied: scipy in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from topo-descriptors) (1.6.2)
# Requirement already satisfied: xarray in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from topo-descriptors) (0.19.0)
# Requirement already satisfied: yaconfigobject in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from topo-descriptors) (1.2.3)
# Requirement already satisfied: netcdf4 in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from topo-descriptors) (1.5.6)
# Requirement already satisfied: numpy in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from topo-descriptors) (1.19.5)
# Requirement already satisfied: utm in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from topo-descriptors) (0.7.0)
# Requirement already satisfied: cftime in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from netcdf4->topo-descriptors) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from pandas->topo-descriptors) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from pandas->topo-descriptors) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->topo-descriptors) (1.15.0)
# Requirement already satisfied: setuptools>=40.4 in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from xarray->topo-descriptors) (58.0.4)
# Requirement already satisfied: pyyaml in /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages (from yaconfigobject->topo-descriptors) (5.4.1)

# %%
from dotenv import load_dotenv
load_dotenv()
import numpy as np
import tensorflow as tf
import tensorflow.keras.callbacks as cb
print(f"Num GPUs Available: {len(tf.config.list_physical_devices('GPU'))}")
# Out:
# Num GPUs Available: 0

# %% [markdown]
# ## Set configuration

# %%
DATA_ROOT = Path('./data')
ERA5_DATA_FOLDER = DATA_ROOT / 'ERA5'
COSMO1_DATA_FOLDER = DATA_ROOT / 'COSMO1'
DEM_DATA_FILE = DATA_ROOT / 'dem/Switzerland-90m-DEM.tif'
PROCESSED_DATA_FOLDER = DATA_ROOT / 'img_prediction_files'

DATA_ROOT.mkdir(parents=True, exist_ok=True)
ERA5_DATA_FOLDER.mkdir(exist_ok=True)
COSMO1_DATA_FOLDER.mkdir(exist_ok=True)
DEM_DATA_FILE.parent.mkdir(exist_ok=True)
PROCESSED_DATA_FOLDER.mkdir(exist_ok=True)

# %%
ERA5_PREDICTORS_SURFACE = ('u10', 'v10', 'blh', 'fsr', 'sp', 'sshf',
                               'u100', 'v100')
ERA5_PREDICTORS_Z500 = ('d', 'z', 'u', 'v', 'w', 'vo')
TOPO_PREDICTORS = ('tpi_500', 'ridge_index_norm', 'ridge_index_dir',
                   'we_derivative', 'sn_derivative',
                   'slope', 'aspect')
HOMEMADE_PREDICTORS = ('e_plus', 'e_minus')
ALL_INPUTS = ['u10', 'v10', 'sp']+ list(HOMEMADE_PREDICTORS) + list(TOPO_PREDICTORS)#ERA5_PREDICTORS_SURFACE + TOPO_PREDICTORS
ALL_OUTPUTS = ['U_10M', 'V_10M']

# %%
# Start and end date for the data - should be in the 2016-2020 range
START_DATE = date(2016,4,1)
END_DATE = date(2017,4,1)
NUM_DAYS = (END_DATE-START_DATE).days + 1
# Number of consecutive images to form a sequence
SEQUENCE_LENGTH = 3
# Size of the high resolution image to be produced
IMG_SIZE = 128
# Number of noise channels to add to the image
NOISE_CHANNELS = 500
# Number of sequences per batch
BATCH_SIZE = 8
# Number of workers to run to process the data to create the batches
BATCH_WORKERS = 8
# Latent dimension for the autoencoder
USE_AUTOENCODER = True
AUTOENCODER_OUTPUT_FEATURES = 8

# %% [markdown]
# ## Data Loading

# %%
from data.download_ERA5 import download_ERA5
download_ERA5(ERA5_DATA_FOLDER, START_DATE, END_DATE)
print('Done')
# Out:
# File 20160401_era5_surface_hourly already exists
# File 20160402_era5_surface_hourly already exists
# File 20160403_era5_surface_hourly already exists
# File 20160404_era5_surface_hourly already exists
# File 20160405_era5_surface_hourly already exists
# File 20160406_era5_surface_hourly already exists
# File 20160407_era5_surface_hourly already exists
# File 20160408_era5_surface_hourly already exists
# File 20160409_era5_surface_hourly already exists
# File 20160410_era5_surface_hourly already exists
# File 20160411_era5_surface_hourly already exists
# File 20160412_era5_surface_hourly already exists
# File 20160413_era5_surface_hourly already exists
# File 20160414_era5_surface_hourly already exists
# File 20160415_era5_surface_hourly already exists
# File 20160416_era5_surface_hourly already exists
# File 20160417_era5_surface_hourly already exists
# File 20160418_era5_surface_hourly already exists
# File 20160419_era5_surface_hourly already exists
# File 20160420_era5_surface_hourly already exists
# File 20160421_era5_surface_hourly already exists
# File 20160422_era5_surface_hourly already exists
# File 20160423_era5_surface_hourly already exists
# File 20160424_era5_surface_hourly already exists
# File 20160425_era5_surface_hourly already exists
# File 20160426_era5_surface_hourly already exists
# File 20160427_era5_surface_hourly already exists
# File 20160428_era5_surface_hourly already exists
# File 20160429_era5_surface_hourly already exists
# File 20160430_era5_surface_hourly already exists
# File 20160501_era5_surface_hourly already exists
# File 20160502_era5_surface_hourly already exists
# File 20160503_era5_surface_hourly already exists
# File 20160504_era5_surface_hourly already exists
# File 20160505_era5_surface_hourly already exists
# File 20160506_era5_surface_hourly already exists
# File 20160507_era5_surface_hourly already exists
# File 20160508_era5_surface_hourly already exists
# File 20160509_era5_surface_hourly already exists
# File 20160510_era5_surface_hourly already exists
# File 20160511_era5_surface_hourly already exists
# File 20160512_era5_surface_hourly already exists
# File 20160513_era5_surface_hourly already exists
# File 20160514_era5_surface_hourly already exists
# File 20160515_era5_surface_hourly already exists
# File 20160516_era5_surface_hourly already exists
# File 20160517_era5_surface_hourly already exists
# File 20160518_era5_surface_hourly already exists
# File 20160519_era5_surface_hourly already exists
# File 20160520_era5_surface_hourly already exists
# File 20160521_era5_surface_hourly already exists
# File 20160522_era5_surface_hourly already exists
# File 20160523_era5_surface_hourly already exists
# File 20160524_era5_surface_hourly already exists
# File 20160525_era5_surface_hourly already exists
# File 20160526_era5_surface_hourly already exists
# File 20160527_era5_surface_hourly already exists
# File 20160528_era5_surface_hourly already exists
# File 20160529_era5_surface_hourly already exists
# File 20160530_era5_surface_hourly already exists
# File 20160531_era5_surface_hourly already exists
# File 20160601_era5_surface_hourly already exists
# File 20160602_era5_surface_hourly already exists
# File 20160603_era5_surface_hourly already exists
# File 20160604_era5_surface_hourly already exists
# File 20160605_era5_surface_hourly already exists
# File 20160606_era5_surface_hourly already exists
# File 20160607_era5_surface_hourly already exists
# File 20160608_era5_surface_hourly already exists
# File 20160609_era5_surface_hourly already exists
# File 20160610_era5_surface_hourly already exists
# File 20160611_era5_surface_hourly already exists
# File 20160612_era5_surface_hourly already exists
# File 20160613_era5_surface_hourly already exists
# File 20160614_era5_surface_hourly already exists
# File 20160615_era5_surface_hourly already exists
# File 20160616_era5_surface_hourly already exists
# File 20160617_era5_surface_hourly already exists
# File 20160618_era5_surface_hourly already exists
# File 20160619_era5_surface_hourly already exists
# File 20160620_era5_surface_hourly already exists
# File 20160621_era5_surface_hourly already exists
# File 20160622_era5_surface_hourly already exists
# File 20160623_era5_surface_hourly already exists
# File 20160624_era5_surface_hourly already exists
# File 20160625_era5_surface_hourly already exists
# File 20160626_era5_surface_hourly already exists
# File 20160627_era5_surface_hourly already exists
# File 20160628_era5_surface_hourly already exists
# File 20160629_era5_surface_hourly already exists
# File 20160630_era5_surface_hourly already exists
# File 20160701_era5_surface_hourly already exists
# File 20160702_era5_surface_hourly already exists
# File 20160703_era5_surface_hourly already exists
# File 20160704_era5_surface_hourly already exists
# File 20160705_era5_surface_hourly already exists
# File 20160706_era5_surface_hourly already exists
# File 20160707_era5_surface_hourly already exists
# File 20160708_era5_surface_hourly already exists
# File 20160709_era5_surface_hourly already exists
# File 20160710_era5_surface_hourly already exists
# File 20160711_era5_surface_hourly already exists
# File 20160712_era5_surface_hourly already exists
# File 20160713_era5_surface_hourly already exists
# File 20160714_era5_surface_hourly already exists
# File 20160715_era5_surface_hourly already exists
# File 20160716_era5_surface_hourly already exists
# File 20160717_era5_surface_hourly already exists
# File 20160718_era5_surface_hourly already exists
# File 20160719_era5_surface_hourly already exists
# File 20160720_era5_surface_hourly already exists
# File 20160721_era5_surface_hourly already exists
# File 20160722_era5_surface_hourly already exists
# File 20160723_era5_surface_hourly already exists
# File 20160724_era5_surface_hourly already exists
# File 20160725_era5_surface_hourly already exists
# File 20160726_era5_surface_hourly already exists
# File 20160727_era5_surface_hourly already exists
# File 20160728_era5_surface_hourly already exists
# File 20160729_era5_surface_hourly already exists
# File 20160730_era5_surface_hourly already exists
# File 20160731_era5_surface_hourly already exists
# File 20160801_era5_surface_hourly already exists
# File 20160802_era5_surface_hourly already exists
# File 20160803_era5_surface_hourly already exists
# File 20160804_era5_surface_hourly already exists
# File 20160805_era5_surface_hourly already exists
# File 20160806_era5_surface_hourly already exists
# File 20160807_era5_surface_hourly already exists
# File 20160808_era5_surface_hourly already exists
# File 20160809_era5_surface_hourly already exists
# File 20160810_era5_surface_hourly already exists
# File 20160811_era5_surface_hourly already exists
# File 20160812_era5_surface_hourly already exists
# File 20160813_era5_surface_hourly already exists
# File 20160814_era5_surface_hourly already exists
# File 20160815_era5_surface_hourly already exists
# File 20160816_era5_surface_hourly already exists
# File 20160817_era5_surface_hourly already exists
# File 20160818_era5_surface_hourly already exists
# File 20160819_era5_surface_hourly already exists
# File 20160820_era5_surface_hourly already exists
# File 20160821_era5_surface_hourly already exists
# File 20160822_era5_surface_hourly already exists
# File 20160823_era5_surface_hourly already exists
# File 20160824_era5_surface_hourly already exists
# File 20160825_era5_surface_hourly already exists
# File 20160826_era5_surface_hourly already exists
# File 20160827_era5_surface_hourly already exists
# File 20160828_era5_surface_hourly already exists
# File 20160829_era5_surface_hourly already exists
# File 20160830_era5_surface_hourly already exists
# File 20160831_era5_surface_hourly already exists
# File 20160901_era5_surface_hourly already exists
# File 20160902_era5_surface_hourly already exists
# File 20160903_era5_surface_hourly already exists
# File 20160904_era5_surface_hourly already exists
# File 20160905_era5_surface_hourly already exists
# File 20160906_era5_surface_hourly already exists
# File 20160907_era5_surface_hourly already exists
# File 20160908_era5_surface_hourly already exists
# File 20160909_era5_surface_hourly already exists
# File 20160910_era5_surface_hourly already exists
# File 20160911_era5_surface_hourly already exists
# File 20160912_era5_surface_hourly already exists
# File 20160913_era5_surface_hourly already exists
# File 20160914_era5_surface_hourly already exists
# File 20160915_era5_surface_hourly already exists
# File 20160916_era5_surface_hourly already exists
# File 20160917_era5_surface_hourly already exists
# File 20160918_era5_surface_hourly already exists
# File 20160919_era5_surface_hourly already exists
# File 20160920_era5_surface_hourly already exists
# File 20160921_era5_surface_hourly already exists
# File 20160922_era5_surface_hourly already exists
# File 20160923_era5_surface_hourly already exists
# File 20160924_era5_surface_hourly already exists
# File 20160925_era5_surface_hourly already exists
# File 20160926_era5_surface_hourly already exists
# File 20160927_era5_surface_hourly already exists
# File 20160928_era5_surface_hourly already exists
# File 20160929_era5_surface_hourly already exists
# File 20160930_era5_surface_hourly already exists
# File 20161001_era5_surface_hourly already exists
# File 20161002_era5_surface_hourly already exists
# File 20161003_era5_surface_hourly already exists
# File 20161004_era5_surface_hourly already exists
# File 20161005_era5_surface_hourly already exists
# File 20161006_era5_surface_hourly already exists
# File 20161007_era5_surface_hourly already exists
# File 20161008_era5_surface_hourly already exists
# File 20161009_era5_surface_hourly already exists
# File 20161010_era5_surface_hourly already exists
# File 20161011_era5_surface_hourly already exists
# File 20161012_era5_surface_hourly already exists
# File 20161013_era5_surface_hourly already exists
# File 20161014_era5_surface_hourly already exists
# File 20161015_era5_surface_hourly already exists
# File 20161016_era5_surface_hourly already exists
# File 20161017_era5_surface_hourly already exists
# File 20161018_era5_surface_hourly already exists
# File 20161019_era5_surface_hourly already exists
# File 20161020_era5_surface_hourly already exists
# File 20161021_era5_surface_hourly already exists
# File 20161022_era5_surface_hourly already exists
# File 20161023_era5_surface_hourly already exists
# File 20161024_era5_surface_hourly already exists
# File 20161025_era5_surface_hourly already exists
# File 20161026_era5_surface_hourly already exists
# File 20161027_era5_surface_hourly already exists
# File 20161028_era5_surface_hourly already exists
# File 20161029_era5_surface_hourly already exists
# File 20161030_era5_surface_hourly already exists
# File 20161031_era5_surface_hourly already exists
# File 20161101_era5_surface_hourly already exists
# File 20161102_era5_surface_hourly already exists
# File 20161103_era5_surface_hourly already exists
# File 20161104_era5_surface_hourly already exists
# File 20161105_era5_surface_hourly already exists
# File 20161106_era5_surface_hourly already exists
# File 20161107_era5_surface_hourly already exists
# File 20161108_era5_surface_hourly already exists
# File 20161109_era5_surface_hourly already exists
# File 20161110_era5_surface_hourly already exists
# File 20161111_era5_surface_hourly already exists
# File 20161112_era5_surface_hourly already exists
# File 20161113_era5_surface_hourly already exists
# File 20161114_era5_surface_hourly already exists
# File 20161115_era5_surface_hourly already exists
# File 20161116_era5_surface_hourly already exists
# File 20161117_era5_surface_hourly already exists
# File 20161118_era5_surface_hourly already exists
# File 20161119_era5_surface_hourly already exists
# File 20161120_era5_surface_hourly already exists
# File 20161121_era5_surface_hourly already exists
# File 20161122_era5_surface_hourly already exists
# File 20161123_era5_surface_hourly already exists
# File 20161124_era5_surface_hourly already exists
# File 20161125_era5_surface_hourly already exists
# File 20161126_era5_surface_hourly already exists
# File 20161127_era5_surface_hourly already exists
# File 20161128_era5_surface_hourly already exists
# File 20161129_era5_surface_hourly already exists
# File 20161130_era5_surface_hourly already exists
# File 20161201_era5_surface_hourly already exists
# File 20161202_era5_surface_hourly already exists
# File 20161203_era5_surface_hourly already exists
# File 20161204_era5_surface_hourly already exists
# File 20161205_era5_surface_hourly already exists
# File 20161206_era5_surface_hourly already exists
# File 20161207_era5_surface_hourly already exists
# File 20161208_era5_surface_hourly already exists
# File 20161209_era5_surface_hourly already exists
# File 20161210_era5_surface_hourly already exists
# File 20161211_era5_surface_hourly already exists
# File 20161212_era5_surface_hourly already exists
# File 20161213_era5_surface_hourly already exists
# File 20161214_era5_surface_hourly already exists
# File 20161215_era5_surface_hourly already exists
# File 20161216_era5_surface_hourly already exists
# File 20161217_era5_surface_hourly already exists
# File 20161218_era5_surface_hourly already exists
# File 20161219_era5_surface_hourly already exists
# File 20161220_era5_surface_hourly already exists
# File 20161221_era5_surface_hourly already exists
# File 20161222_era5_surface_hourly already exists
# File 20161223_era5_surface_hourly already exists
# File 20161224_era5_surface_hourly already exists
# File 20161225_era5_surface_hourly already exists
# File 20161226_era5_surface_hourly already exists
# File 20161227_era5_surface_hourly already exists
# File 20161228_era5_surface_hourly already exists
# File 20161229_era5_surface_hourly already exists
# File 20161230_era5_surface_hourly already exists
# File 20161231_era5_surface_hourly already exists
# File 20170101_era5_surface_hourly already exists
# File 20170102_era5_surface_hourly already exists
# File 20170103_era5_surface_hourly already exists
# File 20170104_era5_surface_hourly already exists
# File 20170105_era5_surface_hourly already exists
# File 20170106_era5_surface_hourly already exists
# File 20170107_era5_surface_hourly already exists
# File 20170108_era5_surface_hourly already exists
# File 20170109_era5_surface_hourly already exists
# File 20170110_era5_surface_hourly already exists
# File 20170111_era5_surface_hourly already exists
# File 20170112_era5_surface_hourly already exists
# File 20170113_era5_surface_hourly already exists
# File 20170114_era5_surface_hourly already exists
# File 20170115_era5_surface_hourly already exists
# File 20170116_era5_surface_hourly already exists
# File 20170117_era5_surface_hourly already exists
# File 20170118_era5_surface_hourly already exists
# File 20170119_era5_surface_hourly already exists
# File 20170120_era5_surface_hourly already exists
# File 20170121_era5_surface_hourly already exists
# File 20170122_era5_surface_hourly already exists
# File 20170123_era5_surface_hourly already exists
# File 20170124_era5_surface_hourly already exists
# File 20170125_era5_surface_hourly already exists
# File 20170126_era5_surface_hourly already exists
# File 20170127_era5_surface_hourly already exists
# File 20170128_era5_surface_hourly already exists
# File 20170129_era5_surface_hourly already exists
# File 20170130_era5_surface_hourly already exists
# File 20170131_era5_surface_hourly already exists
# File 20170201_era5_surface_hourly already exists
# File 20170202_era5_surface_hourly already exists
# File 20170203_era5_surface_hourly already exists
# File 20170204_era5_surface_hourly already exists
# File 20170205_era5_surface_hourly already exists
# File 20170206_era5_surface_hourly already exists
# File 20170207_era5_surface_hourly already exists
# File 20170208_era5_surface_hourly already exists
# File 20170209_era5_surface_hourly already exists
# File 20170210_era5_surface_hourly already exists
# File 20170211_era5_surface_hourly already exists
# File 20170212_era5_surface_hourly already exists
# File 20170213_era5_surface_hourly already exists
# File 20170214_era5_surface_hourly already exists
# File 20170215_era5_surface_hourly already exists
# File 20170216_era5_surface_hourly already exists
# File 20170217_era5_surface_hourly already exists
# File 20170218_era5_surface_hourly already exists
# File 20170219_era5_surface_hourly already exists
# File 20170220_era5_surface_hourly already exists
# File 20170221_era5_surface_hourly already exists
# File 20170222_era5_surface_hourly already exists
# File 20170223_era5_surface_hourly already exists
# File 20170224_era5_surface_hourly already exists
# File 20170225_era5_surface_hourly already exists
# File 20170226_era5_surface_hourly already exists
# File 20170227_era5_surface_hourly already exists
# File 20170228_era5_surface_hourly already exists
# File 20170301_era5_surface_hourly already exists
# File 20170302_era5_surface_hourly already exists
# File 20170303_era5_surface_hourly already exists
# File 20170304_era5_surface_hourly already exists
# File 20170305_era5_surface_hourly already exists
# File 20170306_era5_surface_hourly already exists
# File 20170307_era5_surface_hourly already exists
# File 20170308_era5_surface_hourly already exists
# File 20170309_era5_surface_hourly already exists
# File 20170310_era5_surface_hourly already exists
# File 20170311_era5_surface_hourly already exists
# File 20170312_era5_surface_hourly already exists
# File 20170313_era5_surface_hourly already exists
# File 20170314_era5_surface_hourly already exists
# File 20170315_era5_surface_hourly already exists
# File 20170316_era5_surface_hourly already exists
# File 20170317_era5_surface_hourly already exists
# File 20170318_era5_surface_hourly already exists
# File 20170319_era5_surface_hourly already exists
# File 20170320_era5_surface_hourly already exists
# File 20170321_era5_surface_hourly already exists
# File 20170322_era5_surface_hourly already exists
# File 20170323_era5_surface_hourly already exists
# File 20170324_era5_surface_hourly already exists
# File 20170325_era5_surface_hourly already exists
# File 20170326_era5_surface_hourly already exists
# File 20170327_era5_surface_hourly already exists
# File 20170328_era5_surface_hourly already exists
# File 20170329_era5_surface_hourly already exists
# File 20170330_era5_surface_hourly already exists
# File 20170331_era5_surface_hourly already exists
# File 20170401_era5_surface_hourly already exists
# File 20160401_era5_z500_hourly already exists
# File 20160402_era5_z500_hourly already exists
# File 20160403_era5_z500_hourly already exists
# File 20160404_era5_z500_hourly already exists
# File 20160405_era5_z500_hourly already exists
# File 20160406_era5_z500_hourly already exists
# File 20160407_era5_z500_hourly already exists
# File 20160408_era5_z500_hourly already exists
# File 20160409_era5_z500_hourly already exists
# File 20160410_era5_z500_hourly already exists
# File 20160411_era5_z500_hourly already exists
# File 20160412_era5_z500_hourly already exists
# File 20160413_era5_z500_hourly already exists
# File 20160414_era5_z500_hourly already exists
# File 20160415_era5_z500_hourly already exists
# File 20160416_era5_z500_hourly already exists
# File 20160417_era5_z500_hourly already exists
# File 20160418_era5_z500_hourly already exists
# File 20160419_era5_z500_hourly already exists
# File 20160420_era5_z500_hourly already exists
# File 20160421_era5_z500_hourly already exists
# File 20160422_era5_z500_hourly already exists
# File 20160423_era5_z500_hourly already exists
# File 20160424_era5_z500_hourly already exists
# File 20160425_era5_z500_hourly already exists
# File 20160426_era5_z500_hourly already exists
# File 20160427_era5_z500_hourly already exists
# File 20160428_era5_z500_hourly already exists
# File 20160429_era5_z500_hourly already exists
# File 20160430_era5_z500_hourly already exists
# File 20160501_era5_z500_hourly already exists
# File 20160502_era5_z500_hourly already exists
# File 20160503_era5_z500_hourly already exists
# File 20160504_era5_z500_hourly already exists
# File 20160505_era5_z500_hourly already exists
# File 20160506_era5_z500_hourly already exists
# File 20160507_era5_z500_hourly already exists
# File 20160508_era5_z500_hourly already exists
# File 20160509_era5_z500_hourly already exists
# File 20160510_era5_z500_hourly already exists
# File 20160511_era5_z500_hourly already exists
# File 20160512_era5_z500_hourly already exists
# File 20160513_era5_z500_hourly already exists
# File 20160514_era5_z500_hourly already exists
# File 20160515_era5_z500_hourly already exists
# File 20160516_era5_z500_hourly already exists
# File 20160517_era5_z500_hourly already exists
# File 20160518_era5_z500_hourly already exists
# File 20160519_era5_z500_hourly already exists
# File 20160520_era5_z500_hourly already exists
# File 20160521_era5_z500_hourly already exists
# File 20160522_era5_z500_hourly already exists
# File 20160523_era5_z500_hourly already exists
# File 20160524_era5_z500_hourly already exists
# File 20160525_era5_z500_hourly already exists
# File 20160526_era5_z500_hourly already exists
# File 20160527_era5_z500_hourly already exists
# File 20160528_era5_z500_hourly already exists
# File 20160529_era5_z500_hourly already exists
# File 20160530_era5_z500_hourly already exists
# File 20160531_era5_z500_hourly already exists
# File 20160601_era5_z500_hourly already exists
# File 20160602_era5_z500_hourly already exists
# File 20160603_era5_z500_hourly already exists
# File 20160604_era5_z500_hourly already exists
# File 20160605_era5_z500_hourly already exists
# File 20160606_era5_z500_hourly already exists
# File 20160607_era5_z500_hourly already exists
# File 20160608_era5_z500_hourly already exists
# File 20160609_era5_z500_hourly already exists
# File 20160610_era5_z500_hourly already exists
# File 20160611_era5_z500_hourly already exists
# File 20160612_era5_z500_hourly already exists
# File 20160613_era5_z500_hourly already exists
# File 20160614_era5_z500_hourly already exists
# File 20160615_era5_z500_hourly already exists
# File 20160616_era5_z500_hourly already exists
# File 20160617_era5_z500_hourly already exists
# File 20160618_era5_z500_hourly already exists
# File 20160619_era5_z500_hourly already exists
# File 20160620_era5_z500_hourly already exists
# File 20160621_era5_z500_hourly already exists
# File 20160622_era5_z500_hourly already exists
# File 20160623_era5_z500_hourly already exists
# File 20160624_era5_z500_hourly already exists
# File 20160625_era5_z500_hourly already exists
# File 20160626_era5_z500_hourly already exists
# File 20160627_era5_z500_hourly already exists
# File 20160628_era5_z500_hourly already exists
# File 20160629_era5_z500_hourly already exists
# File 20160630_era5_z500_hourly already exists
# File 20160701_era5_z500_hourly already exists
# File 20160702_era5_z500_hourly already exists
# File 20160703_era5_z500_hourly already exists
# File 20160704_era5_z500_hourly already exists
# File 20160705_era5_z500_hourly already exists
# File 20160706_era5_z500_hourly already exists
# File 20160707_era5_z500_hourly already exists
# File 20160708_era5_z500_hourly already exists
# File 20160709_era5_z500_hourly already exists
# File 20160710_era5_z500_hourly already exists
# File 20160711_era5_z500_hourly already exists
# File 20160712_era5_z500_hourly already exists
# File 20160713_era5_z500_hourly already exists
# File 20160714_era5_z500_hourly already exists
# File 20160715_era5_z500_hourly already exists
# File 20160716_era5_z500_hourly already exists
# File 20160717_era5_z500_hourly already exists
# File 20160718_era5_z500_hourly already exists
# File 20160719_era5_z500_hourly already exists
# File 20160720_era5_z500_hourly already exists
# File 20160721_era5_z500_hourly already exists
# File 20160722_era5_z500_hourly already exists
# File 20160723_era5_z500_hourly already exists
# File 20160724_era5_z500_hourly already exists
# File 20160725_era5_z500_hourly already exists
# File 20160726_era5_z500_hourly already exists
# File 20160727_era5_z500_hourly already exists
# File 20160728_era5_z500_hourly already exists
# File 20160729_era5_z500_hourly already exists
# File 20160730_era5_z500_hourly already exists
# File 20160731_era5_z500_hourly already exists
# File 20160801_era5_z500_hourly already exists
# File 20160802_era5_z500_hourly already exists
# File 20160803_era5_z500_hourly already exists
# File 20160804_era5_z500_hourly already exists
# File 20160805_era5_z500_hourly already exists
# File 20160806_era5_z500_hourly already exists
# File 20160807_era5_z500_hourly already exists
# File 20160808_era5_z500_hourly already exists
# File 20160809_era5_z500_hourly already exists
# File 20160810_era5_z500_hourly already exists
# File 20160811_era5_z500_hourly already exists
# File 20160812_era5_z500_hourly already exists
# File 20160813_era5_z500_hourly already exists
# File 20160814_era5_z500_hourly already exists
# File 20160815_era5_z500_hourly already exists
# File 20160816_era5_z500_hourly already exists
# File 20160817_era5_z500_hourly already exists
# File 20160818_era5_z500_hourly already exists
# File 20160819_era5_z500_hourly already exists
# File 20160820_era5_z500_hourly already exists
# File 20160821_era5_z500_hourly already exists
# File 20160822_era5_z500_hourly already exists
# File 20160823_era5_z500_hourly already exists
# File 20160824_era5_z500_hourly already exists
# File 20160825_era5_z500_hourly already exists
# File 20160826_era5_z500_hourly already exists
# File 20160827_era5_z500_hourly already exists
# File 20160828_era5_z500_hourly already exists
# File 20160829_era5_z500_hourly already exists
# File 20160830_era5_z500_hourly already exists
# File 20160831_era5_z500_hourly already exists
# File 20160901_era5_z500_hourly already exists
# File 20160902_era5_z500_hourly already exists
# File 20160903_era5_z500_hourly already exists
# File 20160904_era5_z500_hourly already exists
# File 20160905_era5_z500_hourly already exists
# File 20160906_era5_z500_hourly already exists
# File 20160907_era5_z500_hourly already exists
# File 20160908_era5_z500_hourly already exists
# File 20160909_era5_z500_hourly already exists
# File 20160910_era5_z500_hourly already exists
# File 20160911_era5_z500_hourly already exists
# File 20160912_era5_z500_hourly already exists
# File 20160913_era5_z500_hourly already exists
# File 20160914_era5_z500_hourly already exists
# File 20160915_era5_z500_hourly already exists
# File 20160916_era5_z500_hourly already exists
# File 20160917_era5_z500_hourly already exists
# File 20160918_era5_z500_hourly already exists
# File 20160919_era5_z500_hourly already exists
# File 20160920_era5_z500_hourly already exists
# File 20160921_era5_z500_hourly already exists
# File 20160922_era5_z500_hourly already exists
# File 20160923_era5_z500_hourly already exists
# File 20160924_era5_z500_hourly already exists
# File 20160925_era5_z500_hourly already exists
# File 20160926_era5_z500_hourly already exists
# File 20160927_era5_z500_hourly already exists
# File 20160928_era5_z500_hourly already exists
# File 20160929_era5_z500_hourly already exists
# File 20160930_era5_z500_hourly already exists
# File 20161001_era5_z500_hourly already exists
# File 20161002_era5_z500_hourly already exists
# File 20161003_era5_z500_hourly already exists
# File 20161004_era5_z500_hourly already exists
# File 20161005_era5_z500_hourly already exists
# File 20161006_era5_z500_hourly already exists
# File 20161007_era5_z500_hourly already exists
# File 20161008_era5_z500_hourly already exists
# File 20161009_era5_z500_hourly already exists
# File 20161010_era5_z500_hourly already exists
# File 20161011_era5_z500_hourly already exists
# File 20161012_era5_z500_hourly already exists
# File 20161013_era5_z500_hourly already exists
# File 20161014_era5_z500_hourly already exists
# File 20161015_era5_z500_hourly already exists
# File 20161016_era5_z500_hourly already exists
# File 20161017_era5_z500_hourly already exists
# File 20161018_era5_z500_hourly already exists
# File 20161019_era5_z500_hourly already exists
# File 20161020_era5_z500_hourly already exists
# File 20161021_era5_z500_hourly already exists
# File 20161022_era5_z500_hourly already exists
# File 20161023_era5_z500_hourly already exists
# File 20161024_era5_z500_hourly already exists
# File 20161025_era5_z500_hourly already exists
# File 20161026_era5_z500_hourly already exists
# File 20161027_era5_z500_hourly already exists
# File 20161028_era5_z500_hourly already exists
# File 20161029_era5_z500_hourly already exists
# File 20161030_era5_z500_hourly already exists
# File 20161031_era5_z500_hourly already exists
# File 20161101_era5_z500_hourly already exists
# File 20161102_era5_z500_hourly already exists
# File 20161103_era5_z500_hourly already exists
# File 20161104_era5_z500_hourly already exists
# File 20161105_era5_z500_hourly already exists
# File 20161106_era5_z500_hourly already exists
# File 20161107_era5_z500_hourly already exists
# File 20161108_era5_z500_hourly already exists
# File 20161109_era5_z500_hourly already exists
# File 20161110_era5_z500_hourly already exists
# File 20161111_era5_z500_hourly already exists
# File 20161112_era5_z500_hourly already exists
# File 20161113_era5_z500_hourly already exists
# File 20161114_era5_z500_hourly already exists
# File 20161115_era5_z500_hourly already exists
# File 20161116_era5_z500_hourly already exists
# File 20161117_era5_z500_hourly already exists
# File 20161118_era5_z500_hourly already exists
# File 20161119_era5_z500_hourly already exists
# File 20161120_era5_z500_hourly already exists
# File 20161121_era5_z500_hourly already exists
# File 20161122_era5_z500_hourly already exists
# File 20161123_era5_z500_hourly already exists
# File 20161124_era5_z500_hourly already exists
# File 20161125_era5_z500_hourly already exists
# File 20161126_era5_z500_hourly already exists
# File 20161127_era5_z500_hourly already exists
# File 20161128_era5_z500_hourly already exists
# File 20161129_era5_z500_hourly already exists
# File 20161130_era5_z500_hourly already exists
# File 20161201_era5_z500_hourly already exists
# File 20161202_era5_z500_hourly already exists
# File 20161203_era5_z500_hourly already exists
# File 20161204_era5_z500_hourly already exists
# File 20161205_era5_z500_hourly already exists
# File 20161206_era5_z500_hourly already exists
# File 20161207_era5_z500_hourly already exists
# File 20161208_era5_z500_hourly already exists
# File 20161209_era5_z500_hourly already exists
# File 20161210_era5_z500_hourly already exists
# File 20161211_era5_z500_hourly already exists
# File 20161212_era5_z500_hourly already exists
# File 20161213_era5_z500_hourly already exists
# File 20161214_era5_z500_hourly already exists
# File 20161215_era5_z500_hourly already exists
# File 20161216_era5_z500_hourly already exists
# File 20161217_era5_z500_hourly already exists
# File 20161218_era5_z500_hourly already exists
# File 20161219_era5_z500_hourly already exists
# File 20161220_era5_z500_hourly already exists
# File 20161221_era5_z500_hourly already exists
# File 20161222_era5_z500_hourly already exists
# File 20161223_era5_z500_hourly already exists
# File 20161224_era5_z500_hourly already exists
# File 20161225_era5_z500_hourly already exists
# File 20161226_era5_z500_hourly already exists
# File 20161227_era5_z500_hourly already exists
# File 20161228_era5_z500_hourly already exists
# File 20161229_era5_z500_hourly already exists
# File 20161230_era5_z500_hourly already exists
# File 20161231_era5_z500_hourly already exists
# File 20170101_era5_z500_hourly already exists
# File 20170102_era5_z500_hourly already exists
# File 20170103_era5_z500_hourly already exists
# File 20170104_era5_z500_hourly already exists
# File 20170105_era5_z500_hourly already exists
# File 20170106_era5_z500_hourly already exists
# File 20170107_era5_z500_hourly already exists
# File 20170108_era5_z500_hourly already exists
# File 20170109_era5_z500_hourly already exists
# File 20170110_era5_z500_hourly already exists
# File 20170111_era5_z500_hourly already exists
# File 20170112_era5_z500_hourly already exists
# File 20170113_era5_z500_hourly already exists
# File 20170114_era5_z500_hourly already exists
# File 20170115_era5_z500_hourly already exists
# File 20170116_era5_z500_hourly already exists
# File 20170117_era5_z500_hourly already exists
# File 20170118_era5_z500_hourly already exists
# File 20170119_era5_z500_hourly already exists
# File 20170120_era5_z500_hourly already exists
# File 20170121_era5_z500_hourly already exists
# File 20170122_era5_z500_hourly already exists
# File 20170123_era5_z500_hourly already exists
# File 20170124_era5_z500_hourly already exists
# File 20170125_era5_z500_hourly already exists
# File 20170126_era5_z500_hourly already exists
# File 20170127_era5_z500_hourly already exists
# File 20170128_era5_z500_hourly already exists
# File 20170129_era5_z500_hourly already exists
# File 20170130_era5_z500_hourly already exists
# File 20170131_era5_z500_hourly already exists
# File 20170201_era5_z500_hourly already exists
# File 20170202_era5_z500_hourly already exists
# File 20170203_era5_z500_hourly already exists
# File 20170204_era5_z500_hourly already exists
# File 20170205_era5_z500_hourly already exists
# File 20170206_era5_z500_hourly already exists
# File 20170207_era5_z500_hourly already exists
# File 20170208_era5_z500_hourly already exists
# File 20170209_era5_z500_hourly already exists
# File 20170210_era5_z500_hourly already exists
# File 20170211_era5_z500_hourly already exists
# File 20170212_era5_z500_hourly already exists
# File 20170213_era5_z500_hourly already exists
# File 20170214_era5_z500_hourly already exists
# File 20170215_era5_z500_hourly already exists
# File 20170216_era5_z500_hourly already exists
# File 20170217_era5_z500_hourly already exists
# File 20170218_era5_z500_hourly already exists
# File 20170219_era5_z500_hourly already exists
# File 20170220_era5_z500_hourly already exists
# File 20170221_era5_z500_hourly already exists
# File 20170222_era5_z500_hourly already exists
# File 20170223_era5_z500_hourly already exists
# File 20170224_era5_z500_hourly already exists
# File 20170225_era5_z500_hourly already exists
# File 20170226_era5_z500_hourly already exists
# File 20170227_era5_z500_hourly already exists
# File 20170228_era5_z500_hourly already exists
# File 20170301_era5_z500_hourly already exists
# File 20170302_era5_z500_hourly already exists
# File 20170303_era5_z500_hourly already exists
# File 20170304_era5_z500_hourly already exists
# File 20170305_era5_z500_hourly already exists
# File 20170306_era5_z500_hourly already exists
# File 20170307_era5_z500_hourly already exists
# File 20170308_era5_z500_hourly already exists
# File 20170309_era5_z500_hourly already exists
# File 20170310_era5_z500_hourly already exists
# File 20170311_era5_z500_hourly already exists
# File 20170312_era5_z500_hourly already exists
# File 20170313_era5_z500_hourly already exists
# File 20170314_era5_z500_hourly already exists
# File 20170315_era5_z500_hourly already exists
# File 20170316_era5_z500_hourly already exists
# File 20170317_era5_z500_hourly already exists
# File 20170318_era5_z500_hourly already exists
# File 20170319_era5_z500_hourly already exists
# File 20170320_era5_z500_hourly already exists
# File 20170321_era5_z500_hourly already exists
# File 20170322_era5_z500_hourly already exists
# File 20170323_era5_z500_hourly already exists
# File 20170324_era5_z500_hourly already exists
# File 20170325_era5_z500_hourly already exists
# File 20170326_era5_z500_hourly already exists
# File 20170327_era5_z500_hourly already exists
# File 20170328_era5_z500_hourly already exists
# File 20170329_era5_z500_hourly already exists
# File 20170330_era5_z500_hourly already exists
# File 20170331_era5_z500_hourly already exists
# File 20170401_era5_z500_hourly already exists
# Done

# %%
if not DEM_DATA_FILE.exists():
    dest = str(DEM_DATA_FILE)
    # !eio --product SRTM3 clip -o {dest} --bounds 5.27 45.4 11.03 48.16

# %%
from data.data_processing import process_topographic_variables_file
process_topographic_variables_file(DEM_DATA_FILE)
# Out:
# 2021-10-04 11:49:57,250 INFO Loading /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages/topo_descriptors/config/topo_descriptors.conf.
# 2021-10-04 11:49:57,251 INFO Loading configuration file: /Users/Boubou/opt/anaconda3/envs/downscale_dev/lib/python3.9/site-packages/topo_descriptors/config/topo_descriptors.conf
# Already processed all topo files

# %%
username = os.getenv('COSMO_USERNAME')
password = os.getenv('COSMO_PASSWORD')
from data import download_COSMO1
download_COSMO1(username, password, COSMO1_DATA_FOLDER, START_DATE, END_DATE)
# Out:
# Finished downloading COSMO data

# %%
from data.data_processing import process_imgs
process_imgs(PROCESSED_DATA_FOLDER, ERA5_DATA_FOLDER, COSMO1_DATA_FOLDER, DEM_DATA_FILE.parent,
             surface_variables_included=ERA5_PREDICTORS_SURFACE,
             z500_variables_included=ERA5_PREDICTORS_Z500,
             topo_variables_included=TOPO_PREDICTORS,
             cosmo_variables_included=('U_10M', 'V_10M'),
             start_date=START_DATE, end_date=END_DATE)
print('Done')
# Out:
# Reading DEM data files
# Inputs and outputs for date 20160401 have already been processed.
# Inputs and outputs for date 20160402 have already been processed.
# Inputs and outputs for date 20160403 have already been processed.
# Inputs and outputs for date 20160404 have already been processed.
# Inputs and outputs for date 20160405 have already been processed.
# Inputs and outputs for date 20160406 have already been processed.
# Inputs and outputs for date 20160407 have already been processed.
# Inputs and outputs for date 20160408 have already been processed.
# Inputs and outputs for date 20160409 have already been processed.
# Inputs and outputs for date 20160410 have already been processed.
# Inputs and outputs for date 20160411 have already been processed.
# Inputs and outputs for date 20160412 have already been processed.
# Inputs and outputs for date 20160413 have already been processed.
# Inputs and outputs for date 20160414 have already been processed.
# Inputs and outputs for date 20160415 have already been processed.
# Inputs and outputs for date 20160416 have already been processed.
# Inputs and outputs for date 20160417 have already been processed.
# Inputs and outputs for date 20160418 have already been processed.
# Inputs and outputs for date 20160419 have already been processed.
# Inputs and outputs for date 20160420 have already been processed.
# Inputs and outputs for date 20160421 have already been processed.
# Inputs and outputs for date 20160422 have already been processed.
# Inputs and outputs for date 20160423 have already been processed.
# Inputs and outputs for date 20160424 have already been processed.
# Inputs and outputs for date 20160425 have already been processed.
# Inputs and outputs for date 20160426 have already been processed.
# Inputs and outputs for date 20160427 have already been processed.
# Inputs and outputs for date 20160428 have already been processed.
# Inputs and outputs for date 20160429 have already been processed.
# Inputs and outputs for date 20160430 have already been processed.
# Inputs and outputs for date 20160501 have already been processed.
# Inputs and outputs for date 20160502 have already been processed.
# Inputs and outputs for date 20160503 have already been processed.
# Inputs and outputs for date 20160504 have already been processed.
# Inputs and outputs for date 20160505 have already been processed.
# Inputs and outputs for date 20160506 have already been processed.
# Inputs and outputs for date 20160507 have already been processed.
# Inputs and outputs for date 20160508 have already been processed.
# Inputs and outputs for date 20160509 have already been processed.
# Inputs and outputs for date 20160510 have already been processed.
# Inputs and outputs for date 20160511 have already been processed.
# Inputs and outputs for date 20160512 have already been processed.
# Inputs and outputs for date 20160513 have already been processed.
# Inputs and outputs for date 20160514 have already been processed.
# Inputs and outputs for date 20160515 have already been processed.
# Inputs and outputs for date 20160516 have already been processed.
# Inputs and outputs for date 20160517 have already been processed.
# Inputs and outputs for date 20160518 have already been processed.
# Inputs and outputs for date 20160519 have already been processed.
# Inputs and outputs for date 20160520 have already been processed.
# Inputs and outputs for date 20160521 have already been processed.
# Inputs and outputs for date 20160522 have already been processed.
# Inputs and outputs for date 20160523 have already been processed.
# Inputs and outputs for date 20160524 have already been processed.
# Inputs and outputs for date 20160525 have already been processed.
# Inputs and outputs for date 20160526 have already been processed.
# Inputs and outputs for date 20160527 have already been processed.
# Inputs and outputs for date 20160528 have already been processed.
# Inputs and outputs for date 20160529 have already been processed.
# Inputs and outputs for date 20160530 have already been processed.
# Inputs and outputs for date 20160531 have already been processed.
# Inputs and outputs for date 20160601 have already been processed.
# Inputs and outputs for date 20160602 have already been processed.
# Inputs and outputs for date 20160603 have already been processed.
# Inputs and outputs for date 20160604 have already been processed.
# Inputs and outputs for date 20160605 have already been processed.
# Inputs and outputs for date 20160606 have already been processed.
# Inputs and outputs for date 20160607 have already been processed.
# Inputs and outputs for date 20160608 have already been processed.
# Inputs and outputs for date 20160609 have already been processed.
# Inputs and outputs for date 20160610 have already been processed.
# Inputs and outputs for date 20160611 have already been processed.
# Inputs and outputs for date 20160612 have already been processed.
# Inputs and outputs for date 20160613 have already been processed.
# Inputs and outputs for date 20160614 have already been processed.
# Inputs and outputs for date 20160615 have already been processed.
# Inputs and outputs for date 20160616 have already been processed.
# Inputs and outputs for date 20160617 have already been processed.
# Inputs and outputs for date 20160618 have already been processed.
# Inputs and outputs for date 20160619 have already been processed.
# Inputs and outputs for date 20160620 have already been processed.
# Inputs and outputs for date 20160621 have already been processed.
# Inputs and outputs for date 20160622 have already been processed.
# Inputs and outputs for date 20160623 have already been processed.
# Inputs and outputs for date 20160624 have already been processed.
# Inputs and outputs for date 20160625 have already been processed.
# Inputs and outputs for date 20160626 have already been processed.
# Inputs and outputs for date 20160627 have already been processed.
# Inputs and outputs for date 20160628 have already been processed.
# Inputs and outputs for date 20160629 have already been processed.
# Inputs and outputs for date 20160630 have already been processed.
# Inputs and outputs for date 20160701 have already been processed.
# Inputs and outputs for date 20160702 have already been processed.
# Inputs and outputs for date 20160703 have already been processed.
# Inputs and outputs for date 20160704 have already been processed.
# Inputs and outputs for date 20160705 have already been processed.
# Inputs and outputs for date 20160706 have already been processed.
# Inputs and outputs for date 20160707 have already been processed.
# Inputs and outputs for date 20160708 have already been processed.
# Inputs and outputs for date 20160709 have already been processed.
# Inputs and outputs for date 20160710 have already been processed.
# Inputs and outputs for date 20160711 have already been processed.
# Inputs and outputs for date 20160712 have already been processed.
# Inputs and outputs for date 20160713 have already been processed.
# Inputs and outputs for date 20160714 have already been processed.
# Inputs and outputs for date 20160715 have already been processed.
# Inputs and outputs for date 20160716 have already been processed.
# Inputs and outputs for date 20160717 have already been processed.
# Inputs and outputs for date 20160718 have already been processed.
# Inputs and outputs for date 20160719 have already been processed.
# Inputs and outputs for date 20160720 have already been processed.
# Inputs and outputs for date 20160721 have already been processed.
# Inputs and outputs for date 20160722 have already been processed.
# Inputs and outputs for date 20160723 have already been processed.
# Inputs and outputs for date 20160724 have already been processed.
# Inputs and outputs for date 20160725 have already been processed.
# Inputs and outputs for date 20160726 have already been processed.
# Inputs and outputs for date 20160727 have already been processed.
# Inputs and outputs for date 20160728 have already been processed.
# Inputs and outputs for date 20160729 have already been processed.
# Inputs and outputs for date 20160730 have already been processed.
# Inputs and outputs for date 20160731 have already been processed.
# Inputs and outputs for date 20160801 have already been processed.
# Inputs and outputs for date 20160802 have already been processed.
# Inputs and outputs for date 20160803 have already been processed.
# Inputs and outputs for date 20160804 have already been processed.
# Inputs and outputs for date 20160805 have already been processed.
# Inputs and outputs for date 20160806 have already been processed.
# Inputs and outputs for date 20160807 have already been processed.
# Inputs and outputs for date 20160808 have already been processed.
# Inputs and outputs for date 20160809 have already been processed.
# Inputs and outputs for date 20160810 have already been processed.
# Inputs and outputs for date 20160811 have already been processed.
# Inputs and outputs for date 20160812 have already been processed.
# Inputs and outputs for date 20160813 have already been processed.
# Inputs and outputs for date 20160814 have already been processed.
# Inputs and outputs for date 20160815 have already been processed.
# Inputs and outputs for date 20160816 have already been processed.
# Inputs and outputs for date 20160817 have already been processed.
# Inputs and outputs for date 20160818 have already been processed.
# Inputs and outputs for date 20160819 have already been processed.
# Inputs and outputs for date 20160820 have already been processed.
# Inputs and outputs for date 20160821 have already been processed.
# Inputs and outputs for date 20160822 have already been processed.
# Inputs and outputs for date 20160823 have already been processed.
# Inputs and outputs for date 20160824 have already been processed.
# Inputs and outputs for date 20160825 have already been processed.
# Inputs and outputs for date 20160826 have already been processed.
# Inputs and outputs for date 20160827 have already been processed.
# Inputs and outputs for date 20160828 have already been processed.
# Inputs and outputs for date 20160829 have already been processed.
# Inputs and outputs for date 20160830 have already been processed.
# Inputs and outputs for date 20160831 have already been processed.
# Inputs and outputs for date 20160901 have already been processed.
# Inputs and outputs for date 20160902 have already been processed.
# Inputs and outputs for date 20160903 have already been processed.
# Inputs and outputs for date 20160904 have already been processed.
# Inputs and outputs for date 20160905 have already been processed.
# Inputs and outputs for date 20160906 have already been processed.
# Inputs and outputs for date 20160907 have already been processed.
# Inputs and outputs for date 20160908 have already been processed.
# Inputs and outputs for date 20160909 have already been processed.
# Inputs and outputs for date 20160910 have already been processed.
# Inputs and outputs for date 20160911 have already been processed.
# Inputs and outputs for date 20160912 have already been processed.
# Inputs and outputs for date 20160913 have already been processed.
# Inputs and outputs for date 20160914 have already been processed.
# Inputs and outputs for date 20160915 have already been processed.
# Inputs and outputs for date 20160916 have already been processed.
# Inputs and outputs for date 20160917 have already been processed.
# Inputs and outputs for date 20160918 have already been processed.
# Inputs and outputs for date 20160919 have already been processed.
# Inputs and outputs for date 20160920 have already been processed.
# Inputs and outputs for date 20160921 have already been processed.
# Inputs and outputs for date 20160922 have already been processed.
# Inputs and outputs for date 20160923 have already been processed.
# Inputs and outputs for date 20160924 have already been processed.
# Inputs and outputs for date 20160925 have already been processed.
# Inputs and outputs for date 20160926 have already been processed.
# Inputs and outputs for date 20160927 have already been processed.
# Inputs and outputs for date 20160928 have already been processed.
# Inputs and outputs for date 20160929 have already been processed.
# Inputs and outputs for date 20160930 have already been processed.
# Inputs and outputs for date 20161001 have already been processed.
# Inputs and outputs for date 20161002 have already been processed.
# Inputs and outputs for date 20161003 have already been processed.
# Inputs and outputs for date 20161004 have already been processed.
# Inputs and outputs for date 20161005 have already been processed.
# Inputs and outputs for date 20161006 have already been processed.
# Inputs and outputs for date 20161007 have already been processed.
# Inputs and outputs for date 20161008 have already been processed.
# Inputs and outputs for date 20161009 have already been processed.
# Inputs and outputs for date 20161010 have already been processed.
# Inputs and outputs for date 20161011 have already been processed.
# Inputs and outputs for date 20161012 have already been processed.
# Inputs and outputs for date 20161013 have already been processed.
# Inputs and outputs for date 20161014 have already been processed.
# Inputs and outputs for date 20161015 have already been processed.
# Inputs and outputs for date 20161016 have already been processed.
# Inputs and outputs for date 20161017 have already been processed.
# Inputs and outputs for date 20161018 have already been processed.
# Inputs and outputs for date 20161019 have already been processed.
# Inputs and outputs for date 20161020 have already been processed.
# Inputs and outputs for date 20161021 have already been processed.
# Inputs and outputs for date 20161022 have already been processed.
# Inputs and outputs for date 20161023 have already been processed.
# Inputs and outputs for date 20161024 have already been processed.
# Inputs and outputs for date 20161025 have already been processed.
# Inputs and outputs for date 20161026 have already been processed.
# Inputs and outputs for date 20161027 have already been processed.
# Inputs and outputs for date 20161028 have already been processed.
# Inputs and outputs for date 20161029 have already been processed.
# Inputs and outputs for date 20161030 have already been processed.
# Inputs and outputs for date 20161031 have already been processed.
# Inputs and outputs for date 20161101 have already been processed.
# Inputs and outputs for date 20161102 have already been processed.
# Inputs and outputs for date 20161103 have already been processed.
# Inputs and outputs for date 20161104 have already been processed.
# Inputs and outputs for date 20161105 have already been processed.
# Inputs and outputs for date 20161106 have already been processed.
# Inputs and outputs for date 20161107 have already been processed.
# Inputs and outputs for date 20161108 have already been processed.
# Inputs and outputs for date 20161109 have already been processed.
# Inputs and outputs for date 20161110 have already been processed.
# Inputs and outputs for date 20161111 have already been processed.
# Inputs and outputs for date 20161112 have already been processed.
# Inputs and outputs for date 20161113 have already been processed.
# Inputs and outputs for date 20161114 have already been processed.
# Inputs and outputs for date 20161115 have already been processed.
# Inputs and outputs for date 20161116 have already been processed.
# Inputs and outputs for date 20161117 have already been processed.
# Inputs and outputs for date 20161118 have already been processed.
# Inputs and outputs for date 20161119 have already been processed.
# Inputs and outputs for date 20161120 have already been processed.
# Inputs and outputs for date 20161121 have already been processed.
# Inputs and outputs for date 20161122 have already been processed.
# Inputs and outputs for date 20161123 have already been processed.
# Inputs and outputs for date 20161124 have already been processed.
# Inputs and outputs for date 20161125 have already been processed.
# Inputs and outputs for date 20161126 have already been processed.
# Inputs and outputs for date 20161127 have already been processed.
# Inputs and outputs for date 20161128 have already been processed.
# Inputs and outputs for date 20161129 have already been processed.
# Inputs and outputs for date 20161130 have already been processed.
# Inputs and outputs for date 20161201 have already been processed.
# Inputs and outputs for date 20161202 have already been processed.
# Inputs and outputs for date 20161203 have already been processed.
# Inputs and outputs for date 20161204 have already been processed.
# Inputs and outputs for date 20161205 have already been processed.
# Inputs and outputs for date 20161206 have already been processed.
# Inputs and outputs for date 20161207 have already been processed.
# Inputs and outputs for date 20161208 have already been processed.
# Inputs and outputs for date 20161209 have already been processed.
# Inputs and outputs for date 20161210 have already been processed.
# Inputs and outputs for date 20161211 have already been processed.
# Inputs and outputs for date 20161212 have already been processed.
# Inputs and outputs for date 20161213 have already been processed.
# Inputs and outputs for date 20161214 have already been processed.
# Inputs and outputs for date 20161215 have already been processed.
# Inputs and outputs for date 20161216 have already been processed.
# Inputs and outputs for date 20161217 have already been processed.
# Inputs and outputs for date 20161218 have already been processed.
# Inputs and outputs for date 20161219 have already been processed.
# Inputs and outputs for date 20161220 have already been processed.
# Inputs and outputs for date 20161221 have already been processed.
# Inputs and outputs for date 20161222 have already been processed.
# Inputs and outputs for date 20161223 have already been processed.
# Inputs and outputs for date 20161224 have already been processed.
# Inputs and outputs for date 20161225 have already been processed.
# Inputs and outputs for date 20161226 have already been processed.
# Inputs and outputs for date 20161227 have already been processed.
# Inputs and outputs for date 20161228 have already been processed.
# Inputs and outputs for date 20161229 have already been processed.
# Inputs and outputs for date 20161230 have already been processed.
# Inputs and outputs for date 20161231 have already been processed.
# Inputs and outputs for date 20170101 have already been processed.
# Inputs and outputs for date 20170102 have already been processed.
# Inputs and outputs for date 20170103 have already been processed.
# Inputs and outputs for date 20170104 have already been processed.
# Inputs and outputs for date 20170105 have already been processed.
# Inputs and outputs for date 20170106 have already been processed.
# Inputs and outputs for date 20170107 have already been processed.
# Inputs and outputs for date 20170108 have already been processed.
# Inputs and outputs for date 20170109 have already been processed.
# Inputs and outputs for date 20170110 have already been processed.
# Inputs and outputs for date 20170111 have already been processed.
# Inputs and outputs for date 20170112 have already been processed.
# Inputs and outputs for date 20170113 have already been processed.
# Inputs and outputs for date 20170114 have already been processed.
# Inputs and outputs for date 20170115 have already been processed.
# Inputs and outputs for date 20170116 have already been processed.
# Inputs and outputs for date 20170117 have already been processed.
# Inputs and outputs for date 20170118 have already been processed.
# Inputs and outputs for date 20170119 have already been processed.
# Inputs and outputs for date 20170120 have already been processed.
# Inputs and outputs for date 20170121 have already been processed.
# Inputs and outputs for date 20170122 have already been processed.
# Inputs and outputs for date 20170123 have already been processed.
# Inputs and outputs for date 20170124 have already been processed.
# Inputs and outputs for date 20170125 have already been processed.
# Inputs and outputs for date 20170126 have already been processed.
# Inputs and outputs for date 20170127 have already been processed.
# Inputs and outputs for date 20170128 have already been processed.
# Inputs and outputs for date 20170129 have already been processed.
# Inputs and outputs for date 20170130 have already been processed.
# Inputs and outputs for date 20170131 have already been processed.
# Inputs and outputs for date 20170201 have already been processed.
# Inputs and outputs for date 20170202 have already been processed.
# Inputs and outputs for date 20170203 have already been processed.
# Inputs and outputs for date 20170204 have already been processed.
# Inputs and outputs for date 20170205 have already been processed.
# Inputs and outputs for date 20170206 have already been processed.
# Inputs and outputs for date 20170207 have already been processed.
# Inputs and outputs for date 20170208 have already been processed.
# Inputs and outputs for date 20170209 have already been processed.
# Inputs and outputs for date 20170210 have already been processed.
# Inputs and outputs for date 20170211 have already been processed.
# Inputs and outputs for date 20170212 have already been processed.
# Inputs and outputs for date 20170213 have already been processed.
# Inputs and outputs for date 20170214 have already been processed.
# Inputs and outputs for date 20170215 have already been processed.
# Inputs and outputs for date 20170216 have already been processed.
# Inputs and outputs for date 20170217 have already been processed.
# Inputs and outputs for date 20170218 have already been processed.
# Inputs and outputs for date 20170219 have already been processed.
# Inputs and outputs for date 20170220 have already been processed.
# Inputs and outputs for date 20170221 have already been processed.
# Inputs and outputs for date 20170222 have already been processed.
# Inputs and outputs for date 20170223 have already been processed.
# Inputs and outputs for date 20170224 have already been processed.
# Inputs and outputs for date 20170225 have already been processed.
# Inputs and outputs for date 20170226 have already been processed.
# Inputs and outputs for date 20170227 have already been processed.
# Inputs and outputs for date 20170228 have already been processed.
# Inputs and outputs for date 20170301 have already been processed.
# Inputs and outputs for date 20170302 have already been processed.
# Inputs and outputs for date 20170303 have already been processed.
# Inputs and outputs for date 20170304 have already been processed.
# Inputs and outputs for date 20170305 have already been processed.
# Inputs and outputs for date 20170306 have already been processed.
# Inputs and outputs for date 20170307 have already been processed.
# Inputs and outputs for date 20170308 have already been processed.
# Inputs and outputs for date 20170309 have already been processed.
# Inputs and outputs for date 20170310 have already been processed.
# Inputs and outputs for date 20170311 have already been processed.
# Inputs and outputs for date 20170312 have already been processed.
# Inputs and outputs for date 20170313 have already been processed.
# Inputs and outputs for date 20170314 have already been processed.
# Inputs and outputs for date 20170315 have already been processed.
# Inputs and outputs for date 20170316 have already been processed.
# Inputs and outputs for date 20170317 have already been processed.
# Inputs and outputs for date 20170318 have already been processed.
# Inputs and outputs for date 20170319 have already been processed.
# Inputs and outputs for date 20170320 have already been processed.
# Inputs and outputs for date 20170321 have already been processed.
# Inputs and outputs for date 20170322 have already been processed.
# Inputs and outputs for date 20170323 have already been processed.
# Inputs and outputs for date 20170324 have already been processed.
# Inputs and outputs for date 20170325 have already been processed.
# Inputs and outputs for date 20170326 have already been processed.
# Inputs and outputs for date 20170327 have already been processed.
# Inputs and outputs for date 20170328 have already been processed.
# Inputs and outputs for date 20170329 have already been processed.
# Inputs and outputs for date 20170330 have already been processed.
# Inputs and outputs for date 20170331 have already been processed.
# Inputs and outputs for date 20170401 have already been processed.
# Done

# %%
from data.data_generator import BatchGenerator, NaiveDecoder

batch_gen = BatchGenerator(path_to_data=PROCESSED_DATA_FOLDER, decoder=NaiveDecoder(normalize=True),
                           sequence_length=SEQUENCE_LENGTH,
                           patch_length_pixel=IMG_SIZE, batch_size=BATCH_SIZE,
                           input_variables=ALL_INPUTS,
                           output_variables= ALL_OUTPUTS,
                           start_date=START_DATE, end_date=END_DATE,
                           num_workers=BATCH_WORKERS)

inputs = []
outputs = []
with batch_gen as batch:
    for b in range(NUM_DAYS):
        print(f'Creating batch {b+1}/{NUM_DAYS}')
        x, y = next(batch)
        inputs.append(x)
        outputs.append(y)
inputs = np.concatenate(inputs, axis=0)
outputs = np.concatenate(outputs, axis=0)
print(f"Inputs: {inputs.shape}")
print(f"Outputs: {outputs.shape}")
# Out:
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Creating batch 1/366
# 2021-10-04 11:51:23,412 WARNING multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Creating batch 2/366
# Creating batch 3/366
# Creating batch 4/366
# Creating batch 5/366
# Creating batch 6/366
# Creating batch 7/366
# Creating batch 8/366
# Creating batch 9/366
# Creating batch 10/366
# Creating batch 11/366
# Creating batch 12/366
# Creating batch 13/366
# Creating batch 14/366
# Creating batch 15/366
# Creating batch 16/366
# Creating batch 17/366
# Creating batch 18/366
# Creating batch 19/366
# Creating batch 20/366
# Creating batch 21/366
# Creating batch 22/366
# Creating batch 23/366
# Creating batch 24/366
# Creating batch 25/366
# Creating batch 26/366
# Creating batch 27/366
# Creating batch 28/366
# Creating batch 29/366
# Creating batch 30/366
# Creating batch 31/366
# Creating batch 32/366
# Creating batch 33/366
# Creating batch 34/366
# Creating batch 35/366
# Creating batch 36/366
# Creating batch 37/366
# Creating batch 38/366
# Creating batch 39/366
# Creating batch 40/366
# Creating batch 41/366
# Creating batch 42/366
# Creating batch 43/366
# Creating batch 44/366
# Creating batch 45/366
# Creating batch 46/366
# Creating batch 47/366
# Creating batch 48/366
# Creating batch 49/366
# Creating batch 50/366
# Creating batch 51/366
# Creating batch 52/366
# Creating batch 53/366
# Creating batch 54/366
# Creating batch 55/366
# Creating batch 56/366
# Creating batch 57/366
# Creating batch 58/366
# Creating batch 59/366
# Creating batch 60/366
# Creating batch 61/366
# Creating batch 62/366
# Creating batch 63/366
# Creating batch 64/366
# Creating batch 65/366
# Creating batch 66/366
# Creating batch 67/366
# Creating batch 68/366
# Creating batch 69/366
# Creating batch 70/366
# Creating batch 71/366
# Creating batch 72/366
# Creating batch 73/366
# Creating batch 74/366
# Creating batch 75/366
# Creating batch 76/366
# Creating batch 77/366
# Creating batch 78/366
# Creating batch 79/366
# Creating batch 80/366
# Creating batch 81/366
# Creating batch 82/366
# Creating batch 83/366
# Creating batch 84/366
# Creating batch 85/366
# Creating batch 86/366
# Creating batch 87/366
# Creating batch 88/366
# Creating batch 89/366
# Creating batch 90/366
# Creating batch 91/366
# Creating batch 92/366
# Creating batch 93/366
# Creating batch 94/366
# Creating batch 95/366
# Creating batch 96/366
# Creating batch 97/366
# Creating batch 98/366
# Creating batch 99/366
# Creating batch 100/366
# Creating batch 101/366
# Creating batch 102/366
# Creating batch 103/366
# Creating batch 104/366
# Creating batch 105/366
# Creating batch 106/366
# Creating batch 107/366
# Creating batch 108/366
# Creating batch 109/366
# Creating batch 110/366
# Creating batch 111/366
# Creating batch 112/366
# Creating batch 113/366
# Creating batch 114/366
# Creating batch 115/366
# Creating batch 116/366
# Creating batch 117/366
# Creating batch 118/366
# Creating batch 119/366
# Creating batch 120/366
# Creating batch 121/366
# Creating batch 122/366
# Creating batch 123/366
# Creating batch 124/366
# Creating batch 125/366
# Creating batch 126/366
# Creating batch 127/366
# Creating batch 128/366
# Creating batch 129/366
# Creating batch 130/366
# Creating batch 131/366
# Creating batch 132/366
# Creating batch 133/366
# Creating batch 134/366
# Creating batch 135/366
# Creating batch 136/366
# Creating batch 137/366
# Creating batch 138/366
# Creating batch 139/366
# Creating batch 140/366
# Creating batch 141/366
# Creating batch 142/366
# Creating batch 143/366
# Creating batch 144/366
# Creating batch 145/366
# Creating batch 146/366
# Creating batch 147/366
# Creating batch 148/366
# Creating batch 149/366
# Creating batch 150/366
# Creating batch 151/366
# Creating batch 152/366
# Creating batch 153/366
# Creating batch 154/366
# Creating batch 155/366
# Creating batch 156/366
# Creating batch 157/366
# Creating batch 158/366
# Creating batch 159/366
# Creating batch 160/366
# Creating batch 161/366
# Creating batch 162/366
# Creating batch 163/366
# Creating batch 164/366
# Creating batch 165/366
# Creating batch 166/366
# Creating batch 167/366
# Creating batch 168/366
# Creating batch 169/366
# Creating batch 170/366
# Creating batch 171/366
# Creating batch 172/366
# Creating batch 173/366
# Creating batch 174/366
# Creating batch 175/366
# Creating batch 176/366
# Creating batch 177/366
# Creating batch 178/366
# Creating batch 179/366
# Creating batch 180/366
# Creating batch 181/366
# Creating batch 182/366
# Creating batch 183/366
# Creating batch 184/366
# Creating batch 185/366
# Creating batch 186/366
# Creating batch 187/366
# Creating batch 188/366
# Creating batch 189/366
# Creating batch 190/366
# Creating batch 191/366
# Creating batch 192/366
# Creating batch 193/366
# Creating batch 194/366
# Creating batch 195/366
# Creating batch 196/366
# Creating batch 197/366
# Creating batch 198/366
# Creating batch 199/366
# Creating batch 200/366
# Creating batch 201/366
# Creating batch 202/366
# Creating batch 203/366
# Creating batch 204/366
# Creating batch 205/366
# Creating batch 206/366
# Creating batch 207/366
# Creating batch 208/366
# Creating batch 209/366
# Creating batch 210/366
# Creating batch 211/366
# Creating batch 212/366
# Creating batch 213/366
# Creating batch 214/366
# Creating batch 215/366
# Creating batch 216/366
# Creating batch 217/366
# Creating batch 218/366
# Creating batch 219/366
# Creating batch 220/366
# Creating batch 221/366
# Creating batch 222/366
# Creating batch 223/366
# Creating batch 224/366
# Creating batch 225/366
# Creating batch 226/366
# Creating batch 227/366
# Creating batch 228/366
# Creating batch 229/366
# Creating batch 230/366
# Creating batch 231/366
# Creating batch 232/366
# Creating batch 233/366
# Creating batch 234/366
# Creating batch 235/366
# Creating batch 236/366
# Creating batch 237/366
# Creating batch 238/366
# Creating batch 239/366
# Creating batch 240/366
# Creating batch 241/366
# Creating batch 242/366
# Creating batch 243/366
# Creating batch 244/366
# Creating batch 245/366
# Creating batch 246/366
# Creating batch 247/366
# Creating batch 248/366
# Creating batch 249/366
# Creating batch 250/366
# Creating batch 251/366
# Creating batch 252/366
# Creating batch 253/366
# Creating batch 254/366
# Creating batch 255/366
# Creating batch 256/366
# Creating batch 257/366
# Creating batch 258/366
# Creating batch 259/366
# Creating batch 260/366
# Creating batch 261/366
# Creating batch 262/366
# Creating batch 263/366
# Creating batch 264/366
# Creating batch 265/366
# Creating batch 266/366
# Creating batch 267/366
# Creating batch 268/366
# Creating batch 269/366
# Creating batch 270/366
# Creating batch 271/366
# Creating batch 272/366
# Creating batch 273/366
# Creating batch 274/366
# Creating batch 275/366
# Creating batch 276/366
# Creating batch 277/366
# Creating batch 278/366
# Creating batch 279/366
# Creating batch 280/366
# Creating batch 281/366
# Creating batch 282/366
# Creating batch 283/366
# Creating batch 284/366
# Creating batch 285/366
# Creating batch 286/366
# Creating batch 287/366
# Creating batch 288/366
# Creating batch 289/366
# Creating batch 290/366
# Creating batch 291/366
# Creating batch 292/366
# Creating batch 293/366
# Creating batch 294/366
# Creating batch 295/366
# Creating batch 296/366
# Creating batch 297/366
# Creating batch 298/366
# Creating batch 299/366
# Creating batch 300/366
# Creating batch 301/366
# Creating batch 302/366
# Creating batch 303/366
# Creating batch 304/366
# Creating batch 305/366
# Creating batch 306/366
# Creating batch 307/366
# Creating batch 308/366
# Creating batch 309/366
# Creating batch 310/366
# Creating batch 311/366
# Creating batch 312/366
# Creating batch 313/366
# Creating batch 314/366
# Creating batch 315/366
# Creating batch 316/366
# Creating batch 317/366
# Creating batch 318/366
# Creating batch 319/366
# Creating batch 320/366
# Creating batch 321/366
# Creating batch 322/366
# Creating batch 323/366
# Creating batch 324/366
# Creating batch 325/366
# Creating batch 326/366
# Creating batch 327/366
# Creating batch 328/366
# Creating batch 329/366
# Creating batch 330/366
# Creating batch 331/366
# Creating batch 332/366
# Creating batch 333/366
# Creating batch 334/366
# Creating batch 335/366
# Creating batch 336/366
# Creating batch 337/366
# Creating batch 338/366
# Creating batch 339/366
# Creating batch 340/366
# Creating batch 341/366
# Creating batch 342/366
# Creating batch 343/366
# Creating batch 344/366
# Creating batch 345/366
# Creating batch 346/366
# Creating batch 347/366
# Creating batch 348/366
# Creating batch 349/366
# Creating batch 350/366
# Creating batch 351/366
# Creating batch 352/366
# Creating batch 353/366
# Creating batch 354/366
# Creating batch 355/366
# Creating batch 356/366
# Creating batch 357/366
# Creating batch 358/366
# Creating batch 359/366
# Creating batch 360/366
# Creating batch 361/366
# Creating batch 362/366
# Creating batch 363/366
# Creating batch 364/366
# Creating batch 365/366
# Creating batch 366/366
# Inputs: (2928, 3, 128, 128, 12)
# Outputs: (2928, 3, 128, 128, 2)

# %%
INPUT_CHANNELS = len(ALL_INPUTS)
OUT_CHANNELS = len(ALL_OUTPUTS)
# Out:
# No autoencoder weights found!

# %%
from gan import train, metrics
from gan.models import make_generator_no_noise
generator = make_generator_no_noise(image_size=IMG_SIZE, in_channels=INPUT_CHANNELS,
                            out_channels=OUT_CHANNELS,
                           n_timesteps=SEQUENCE_LENGTH)
print(f"Generator: {generator.count_params():,} weights")
# Out:
# Total: 16,104,731 weights

# %%
generator.compile(optimizer=train.generator_optimizer(),
            metrics= [tf.keras.metrics.RootMeanSquaredError(), metrics.LogSpectralDistance(),
                                metrics.WeightedRMSEForExtremes(), metrics.WindSpeedWeightedRMSE()],
                loss=train.generator_loss)

# %%
checkpoint_path_weights = Path('./checkpoints/generator/weights-{epoch:02d}.ckpt')
checkpoint_path_weights.parent.mkdir(exist_ok=True, parents=True)
log_path = Path('./logs/generator')
if log_path.exists():
    log_path_str = str(log_path)
    # !rm -rf {log_path_str}

# %%
# %load_ext tensorboard
# %tensorboard --logdir=logs/gan
# Out:
#       <iframe id="tensorboard-frame-a59778073535ac8d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a59778073535ac8d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import matplotlib.pyplot as plt
def show(images, dims=1, legends=None):
    fig, axes = plt.subplots(ncols= len(images), figsize=(10, 10))
    for ax, im in zip(axes, images):
        for i in range(dims):
            label = legends[i] if legends is not None else ''
            ax.imshow(im[0, :, :, i], cmap='jet')
            ax.set_title(label)
            ax.axis('off')
    plt.show()
    return fig

# %%
class ShowCallback(tf.keras.callbacks.Callback):
    def __init__(self, dims):
        self.dims = dims
        
    def on_epoch_begin(self, epoch, logs):
        show(self.model.generator(inputs[:self.dims]))

# %%
callbacks = [
    cb.TensorBoard(log_path, write_images=True, update_freq='batch', profile_batch=(2, 4)),
    cb.ProgbarLogger('steps'),
    cb.TerminateOnNaN(),
    ShowCallback(10),
    cb.ModelCheckpoint(str(checkpoint_path_weights), monitor='ws_weighted_rmse', mode='min',
                       save_best_only=False, period=3, save_weights_only=True),
]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2021-10-04 12:08:48,791 WARNING `period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
generator.fit(inputs, outputs, callbacks=callbacks, epochs=20, batch_size=BATCH_SIZE, validation_split=0.25)
# Out:
# Epoch 1/20
#  43/275 [===>..........................] - ETA: 1:09:24 - d_loss: -52.2339 - g_loss: -139.8211 - d_fake: -54.8373 - d_real: -88.0099 - g_root_mean_squared_error: 3.1352 - g_lsd: 13.0234 - g_extreme_rmse: 1.9623 - g_ws_weighted_rmse: 5.2922

# %%
for epoch in [6,8,12,35,40,50]:
    generator.load_weights(f'checkpoints/generator/weights-{epoch:02d}.ckpt')
    if not os.path.exists(f'plots/gan_pred/{epoch}'):
        os.mkdir(f'plots/gan_pred/{epoch}')
    for i in range(0, BATCH_SIZE*6, BATCH_SIZE):
        results = generator.predict(inputs[i:i+BATCH_SIZE])
        j=0
        for inp, out, res in zip(inputs[i:i+BATCH_SIZE], outputs[i:i+BATCH_SIZE], results):
            fig = show([inp, out, res])
            fig.savefig(f'plots/gen_pred/{epoch}/inp_{i}_batch_{j}.png')
            j+=1
